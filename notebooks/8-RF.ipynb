# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Libraries

# %%
from sklearnex import patch_sklearn 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPClassifier
patch_sklearn()
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import time
from collections import Counter
from imblearn.over_sampling import SMOTE, ADASYN, SMOTENC
from imblearn.combine import SMOTETomek, SMOTEENN 
import matplotlib.pyplot as plt
from numpy import where
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
df_train = pd.read_csv('../data/df_train.csv')
df_test = pd.read_csv('../data/df_test.csv')

X_train = df_train.drop('kill', axis=1)
y_train = df_train['kill']
X_test = df_test.drop(['kill'], axis=1)
y_test = df_test['kill']

X_train = X_train.values
y_train = y_train.values
X_test = X_test.values
y_test = y_test.values

# %%
def fit_and_print(model, X_train, y_train):
    model.fit(X_train, y_train)  
    y_pred = model.predict(X_test)
    print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))  
    print("Classification Report: \n", classification_report(y_test, y_pred))  
    print("Accuracy: ", round(accuracy_score(y_test, y_pred),3))
    print("Precision:", round(precision_score(y_test, y_pred),3))
    print("Recall:", round(recall_score(y_test, y_pred),3))
    print("f1: ", round(f1_score(y_test, y_pred),3))

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
fit_and_print(model, X_train, y_train)
# Out:
# Confusion Matrix:
#  [[19836   385]
#  [ 2074   746]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94     20221
#            1       0.66      0.26      0.38      2820
#
#     accuracy                           0.89     23041
#    macro avg       0.78      0.62      0.66     23041
# weighted avg       0.88      0.89      0.87     23041
#
# Accuracy:  0.893
# Precision: 0.66
# Recall: 0.265
# f1:  0.378

# %% [markdown]
# ## GridSearch

# %%
param_grid = {
    'bootstrap': [True],
    'max_features': [2, 3, 4, 5, 6, 7, 8, 9, 10],
    'min_samples_leaf': [3, 5, 8],
    'min_samples_split': [4, 8, 12],
}

# %%
# Create a based model
rf = RandomForestClassifier(random_state=42)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5, n_jobs = -1, verbose = 10)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'bootstrap': [True],
#                          'max_features': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_leaf': [3, 5, 8],
#                          'min_samples_split': [4, 8, 12]},
#              verbose=10)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 5,
#  'min_samples_leaf': 8,
#  'min_samples_split': 4}

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# RandomForestClassifier(max_features=5, min_samples_leaf=8, min_samples_split=4,
#                        random_state=42)

# %%
grid_search.best_score_
# Out:
# 0.89670279171294

# %%
# get the start time
st_wall_inf = time.time()

# Generate generalization metrics
grid_predictions = best_grid.predict(X_test)

# get the end time
et_wall_inf = time.time()

# get execution time
wall_time_inf = et_wall_inf - st_wall_inf
print(f'Inference Time: {wall_time_inf:.3f} seconds')
# Out:
# Inference Time: 0.061 seconds

# %%
fit_and_print(best_grid,X_train,y_train)
# Out:
# Confusion Matrix:
#  [[19882   339]
#  [ 2081   739]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94     20221
#            1       0.69      0.26      0.38      2820
#
#     accuracy                           0.89     23041
#    macro avg       0.80      0.62      0.66     23041
# weighted avg       0.88      0.89      0.87     23041
#
# Accuracy:  0.895
# Precision: 0.686
# Recall: 0.262
# f1:  0.379

# %%
def calculate_pred_and_inf_time(best_grid, X_test):
    # get the start time
    st_wall_inf = time.time()

    # Generate generalization metrics
    grid_predictions = best_grid.predict(X_test)

    # get the end time
    et_wall_inf = time.time()

    # get execution time
    wall_time_inf = et_wall_inf - st_wall_inf
    print(f'Inference Time: {1000*wall_time_inf:.3f} miliseconds')

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Inference Time: 160.834 miliseconds

# %% [markdown]
# ## Resampling

# %% [markdown]
# ### SMOTE

# %%
# Oversample and plot imbalanced dataset with SMOTE

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = SMOTE(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({0: 114988, 1: 114988})
# Confusion Matrix:
#  [[18123  2098]
#  [ 1330  1490]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91     20221
#            1       0.42      0.53      0.47      2820
#
#     accuracy                           0.85     23041
#    macro avg       0.67      0.71      0.69     23041
# weighted avg       0.87      0.85      0.86     23041
#
# Accuracy:  0.851
# Precision: 0.415
# Recall: 0.528
# f1:  0.465
# Inference Time: 108.346 miliseconds

# %% [markdown]
# ### ADASYN

# %%
# Oversample and plot imbalanced dataset with ADASYN

from collections import Counter
from imblearn.over_sampling import SMOTE, ADASYN, SMOTENC
from imblearn.combine import SMOTETomek, SMOTEENN 
import matplotlib.pyplot as plt
from numpy import where

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = ADASYN(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({0: 114988, 1: 112141})
# Confusion Matrix:
#  [[17902  2319]
#  [ 1267  1553]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     20221
#            1       0.40      0.55      0.46      2820
#
#     accuracy                           0.84     23041
#    macro avg       0.67      0.72      0.69     23041
# weighted avg       0.87      0.84      0.85     23041
#
# Accuracy:  0.844
# Precision: 0.401
# Recall: 0.551
# f1:  0.464
# Inference Time: 175.762 miliseconds

# %% [markdown]
# ### SMOTE and TL

# %%
# Oversample and plot imbalanced dataset with SMOTE and TL

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = SMOTETomek(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({0: 106266, 1: 106266})
# Confusion Matrix:
#  [[18021  2200]
#  [ 1306  1514]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     20221
#            1       0.41      0.54      0.46      2820
#
#     accuracy                           0.85     23041
#    macro avg       0.67      0.71      0.69     23041
# weighted avg       0.87      0.85      0.86     23041
#
# Accuracy:  0.848
# Precision: 0.408
# Recall: 0.537
# f1:  0.463
# Inference Time: 350.045 miliseconds

# %% [markdown]
# ### SMOTE and ENN

# %%
# Oversample and plot imbalanced dataset with SMOTE and ENN

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = SMOTEENN(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({1: 79510, 0: 69097})
# Confusion Matrix:
#  [[16759  3462]
#  [  947  1873]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88     20221
#            1       0.35      0.66      0.46      2820
#
#     accuracy                           0.81     23041
#    macro avg       0.65      0.75      0.67     23041
# weighted avg       0.87      0.81      0.83     23041
#
# Accuracy:  0.809
# Precision: 0.351
# Recall: 0.664
# f1:  0.459
# Inference Time: 35.179 miliseconds
# [CV 3/5; 7/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4
# [CV 3/5; 7/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  14.8s
# [CV 5/5; 9/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 9/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  15.2s
# [CV 5/5; 17/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 17/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=8;, score=0.898 total time=  18.9s
# [CV 4/5; 25/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=4
# [CV 4/5; 25/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  22.4s
# [CV 2/5; 33/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 33/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  28.9s
# [CV 4/5; 41/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 41/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  32.0s
# [CV 3/5; 49/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 49/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  38.0s
# [CV 4/5; 57/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 57/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  38.8s
# [CV 1/5; 64/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=4
# [CV 1/5; 64/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=4;, score=0.892 total time=  49.6s
# [CV 4/5; 73/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4
# [CV 4/5; 73/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4;, score=0.894 total time=  53.9s
# [CV 4/5; 3/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 3/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  17.8s
# [CV 1/5; 13/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4
# [CV 1/5; 13/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  23.4s
# [CV 3/5; 23/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 23/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  26.4s
# [CV 3/5; 32/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 32/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  29.4s
# [CV 3/5; 40/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 40/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  35.3s
# [CV 5/5; 49/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4
# [CV 5/5; 49/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  36.1s
# [CV 4/5; 56/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=8
# [CV 4/5; 56/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  41.4s
# [CV 2/5; 65/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8
# [CV 2/5; 65/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  48.4s
# [CV 3/5; 73/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 73/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4;, score=0.894 total time=  53.8s
# [CV 4/5; 8/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8
# [CV 4/5; 8/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8;, score=0.895 total time=  14.7s
# [CV 1/5; 10/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4
# [CV 1/5; 10/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4;, score=0.894 total time=  21.8s
# [CV 3/5; 18/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12
# [CV 3/5; 18/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  22.8s
# [CV 3/5; 26/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 26/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  21.5s
# [CV 3/5; 34/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4
# [CV 3/5; 34/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  27.7s
# [CV 4/5; 42/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12
# [CV 4/5; 42/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  31.2s
# [CV 3/5; 50/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 50/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  37.1s
# [CV 5/5; 58/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4
# [CV 5/5; 58/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  38.8s
# [CV 3/5; 66/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12
# [CV 3/5; 66/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12;, score=0.894 total time=  45.6s
# [CV 3/5; 74/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8
# [CV 3/5; 74/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  51.3s
# [CV 4/5; 4/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 4/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=4;, score=0.894 total time=  18.4s
# [CV 2/5; 12/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=12
# [CV 2/5; 12/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=12;, score=0.898 total time=  21.0s
# [CV 2/5; 19/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4
# [CV 2/5; 19/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4;, score=0.897 total time=  25.7s
# [CV 1/5; 27/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12
# [CV 1/5; 27/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12;, score=0.895 total time=  24.9s
# [CV 3/5; 35/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 35/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  26.3s
# [CV 2/5; 43/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 43/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4;, score=0.898 total time=  28.4s
# [CV 2/5; 51/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 51/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  33.9s
# [CV 4/5; 58/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 58/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  40.9s
# [CV 5/5; 66/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12
# [CV 5/5; 66/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  44.0s
# [CV 5/5; 74/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8
# [CV 5/5; 74/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8;, score=0.894 total time=  52.4s
# [CV 4/5; 7/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4
# [CV 4/5; 7/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4;, score=0.895 total time=  17.0s
# [CV 1/5; 12/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=12
# [CV 1/5; 12/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  21.0s
# [CV 4/5; 18/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 18/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  22.6s
# [CV 4/5; 26/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8
# [CV 4/5; 26/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  22.3s
# [CV 4/5; 34/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4
# [CV 4/5; 34/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  28.3s
# [CV 5/5; 42/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 42/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  30.4s
# [CV 1/5; 51/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12
# [CV 1/5; 51/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12;, score=0.894 total time=  37.5s
# [CV 1/5; 59/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 59/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8;, score=0.894 total time=  40.2s
# [CV 1/5; 67/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4
# [CV 1/5; 67/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4;, score=0.893 total time=  45.1s
# [CV 1/5; 75/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12
# [CV 1/5; 75/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12;, score=0.893 total time=  50.7s
# [CV 2/5; 5/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 5/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  16.7s
# [CV 2/5; 10/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4
# [CV 2/5; 10/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4;, score=0.897 total time=  22.1s
# [CV 5/5; 18/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 18/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12;, score=0.898 total time=  23.9s
# [CV 5/5; 26/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 26/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  21.4s
# [CV 5/5; 34/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4
# [CV 5/5; 34/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  26.6s
# [CV 3/5; 42/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12
# [CV 3/5; 42/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  31.7s
# [CV 4/5; 50/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 50/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  38.7s
# [CV 2/5; 59/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 59/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  39.9s
# [CV 2/5; 67/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 67/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  46.3s
# [CV 2/5; 75/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12
# [CV 2/5; 75/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  49.5s
# [CV 2/5; 7/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 7/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4;, score=0.895 total time=  12.2s
# [CV 3/5; 9/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12
# [CV 3/5; 9/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  12.7s
# [CV 2/5; 16/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 16/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  18.0s
# [CV 5/5; 23/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 23/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  25.6s
# [CV 2/5; 32/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 32/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  28.3s
# [CV 4/5; 39/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 39/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  34.3s
# [CV 1/5; 48/81] START bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=12
# [CV 1/5; 48/81] END bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=12;, score=0.894 total time=  40.4s
# [CV 5/5; 57/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=12
# [CV 5/5; 57/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  43.8s
# [CV 1/5; 66/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12
# [CV 1/5; 66/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12;, score=0.894 total time=  47.5s
# [CV 4/5; 74/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8
# [CV 4/5; 74/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8;, score=0.894 total time=  53.6s
# [CV 5/5; 5/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 5/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  12.3s
# [CV 5/5; 15/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 15/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12;, score=0.898 total time=  18.0s
# [CV 3/5; 22/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 22/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  23.9s
# [CV 5/5; 27/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 27/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  25.8s
# [CV 4/5; 35/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8
# [CV 4/5; 35/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  26.9s
# [CV 4/5; 43/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4
# [CV 4/5; 43/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  29.1s
# [CV 4/5; 51/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12
# [CV 4/5; 51/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  35.9s
# [CV 5/5; 59/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 59/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  40.2s
# [CV 4/5; 67/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 67/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  44.5s
# [CV 3/5; 75/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12
# [CV 3/5; 75/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12;, score=0.894 total time=  50.1s
# [CV 5/5; 3/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=12
# [CV 5/5; 3/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  19.7s
# [CV 5/5; 14/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 14/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  22.1s
# [CV 1/5; 23/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 23/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  25.5s
# [CV 1/5; 31/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=4
# [CV 1/5; 31/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=4;, score=0.894 total time=  27.4s
# [CV 5/5; 36/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 36/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  30.1s
# [CV 5/5; 44/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 44/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  29.1s
# [CV 4/5; 52/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4
# [CV 4/5; 52/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  34.8s
# [CV 4/5; 60/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12
# [CV 4/5; 60/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  39.3s
# [CV 5/5; 68/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 68/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  42.8s
# [CV 2/5; 76/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 76/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  47.9s
# [CV 1/5; 6/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12
# [CV 1/5; 6/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  18.6s
# [CV 2/5; 14/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 14/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8;, score=0.898 total time=  21.2s
# [CV 5/5; 21/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12
# [CV 5/5; 21/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12;, score=0.897 total time=  25.0s
# [CV 2/5; 28/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4
# [CV 2/5; 28/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4;, score=0.897 total time=  28.3s
# [CV 2/5; 36/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12
# [CV 2/5; 36/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12;, score=0.898 total time=  28.2s
# [CV 2/5; 44/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8
# [CV 2/5; 44/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8;, score=0.898 total time=  29.9s
# [CV 2/5; 52/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 52/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  34.6s
# [CV 2/5; 60/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 60/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  41.1s
# [CV 2/5; 68/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 68/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  43.0s
# [CV 5/5; 75/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12
# [CV 5/5; 75/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  49.2s
# [CV 3/5; 8/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 8/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  16.7s
# [CV 5/5; 10/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 10/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4;, score=0.898 total time=  22.8s
# [CV 1/5; 21/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12
# [CV 1/5; 21/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  25.7s
# [CV 1/5; 28/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4
# [CV 1/5; 28/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4;, score=0.893 total time=  29.3s
# [CV 3/5; 36/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12
# [CV 3/5; 36/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  29.3s
# [CV 3/5; 44/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 44/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  30.9s
# [CV 5/5; 52/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4
# [CV 5/5; 52/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  34.8s
# [CV 5/5; 60/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 60/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  38.4s
# [CV 3/5; 68/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 68/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  44.2s
# [CV 3/5; 76/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 76/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  48.3s
# [CV 2/5; 3/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=12
# [CV 2/5; 3/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  18.0s
# [CV 1/5; 11/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 11/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  21.9s
# [CV 1/5; 20/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 20/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  26.8s
# [CV 5/5; 28/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 28/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  29.4s
# [CV 4/5; 36/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 36/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  29.4s
# [CV 4/5; 44/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8
# [CV 4/5; 44/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  29.2s
# [CV 3/5; 52/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4
# [CV 3/5; 52/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  34.5s
# [CV 3/5; 60/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12
# [CV 3/5; 60/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  39.5s
# [CV 4/5; 68/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 68/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  44.4s
# [CV 5/5; 76/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4
# [CV 5/5; 76/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  48.0s
# [CV 5/5; 1/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 1/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  18.4s
# [CV 2/5; 13/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 13/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4;, score=0.898 total time=  20.8s
# [CV 2/5; 20/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=8
# [CV 2/5; 20/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=8;, score=0.897 total time=  26.2s
# [CV 4/5; 27/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 27/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  26.9s
# [CV 5/5; 35/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 35/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  27.2s
# [CV 5/5; 43/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4
# [CV 5/5; 43/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  29.9s
# [CV 1/5; 52/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4
# [CV 1/5; 52/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=4;, score=0.895 total time=  33.4s
# [CV 4/5; 59/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 59/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  40.1s
# [CV 3/5; 67/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 67/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  45.2s
# [CV 4/5; 75/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 75/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  52.3s
# [CV 4/5; 2/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8
# [CV 4/5; 2/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  18.8s
# [CV 1/5; 14/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 14/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  22.0s
# [CV 4/5; 22/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 22/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  24.5s
# [CV 1/5; 29/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 29/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=8;, score=0.894 total time=  27.9s
# [CV 1/5; 36/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12
# [CV 1/5; 36/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=12;, score=0.895 total time=  27.3s
# [CV 1/5; 44/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 44/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=8;, score=0.895 total time=  28.1s
# [CV 5/5; 51/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 51/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  36.4s
# [CV 1/5; 60/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12
# [CV 1/5; 60/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=12;, score=0.894 total time=  41.4s
# [CV 1/5; 68/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 68/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=8;, score=0.893 total time=  44.1s
# [CV 1/5; 76/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4
# [CV 1/5; 76/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4;, score=0.893 total time=  49.7s
# [CV 4/5; 5/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 5/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8;, score=0.894 total time=  17.8s
# [CV 4/5; 10/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4
# [CV 4/5; 10/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  22.0s
# [CV 4/5; 19/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4
# [CV 4/5; 19/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4;, score=0.897 total time=  27.2s
# [CV 4/5; 29/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=8
# [CV 4/5; 29/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  30.1s
# [CV 1/5; 39/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=12
# [CV 1/5; 39/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  33.4s
# [CV 5/5; 45/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 45/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  31.4s
# [CV 2/5; 53/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8
# [CV 2/5; 53/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  34.1s
# [CV 2/5; 61/81] START bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 61/81] END bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4;, score=0.898 total time=  37.0s
# [CV 2/5; 69/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 69/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  41.9s
# [CV 1/5; 77/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 77/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8;, score=0.893 total time=  47.4s
# [CV 3/5; 2/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8
# [CV 3/5; 2/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  18.5s
# [CV 4/5; 13/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 13/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  21.6s
# [CV 1/5; 22/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4
# [CV 1/5; 22/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  24.2s
# [CV 3/5; 27/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12
# [CV 3/5; 27/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  23.8s
# [CV 1/5; 35/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 35/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8;, score=0.895 total time=  27.9s
# [CV 3/5; 43/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4
# [CV 3/5; 43/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  29.0s
# [CV 3/5; 51/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12
# [CV 3/5; 51/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  35.8s
# [CV 3/5; 59/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 59/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  43.5s
# [CV 5/5; 67/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4
# [CV 5/5; 67/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  46.3s
# [CV 4/5; 76/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 76/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  50.4s
# [CV 4/5; 6/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12
# [CV 4/5; 6/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  14.9s
# [CV 1/5; 17/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 17/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=8;, score=0.895 total time=  17.5s
# [CV 3/5; 24/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=12
# [CV 3/5; 24/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  24.1s
# [CV 4/5; 32/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 32/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  27.0s
# [CV 3/5; 37/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 37/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  33.8s
# [CV 3/5; 45/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12
# [CV 3/5; 45/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  33.1s
# [CV 5/5; 53/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 53/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  33.9s
# [CV 4/5; 61/81] START bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4
# [CV 4/5; 61/81] END bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  38.4s
# [CV 3/5; 69/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12
# [CV 3/5; 69/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  41.6s
# [CV 2/5; 77/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 77/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  46.7s
# [CV 1/5; 8/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 8/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8;, score=0.894 total time=  17.0s
# [CV 2/5; 11/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8
# [CV 2/5; 11/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8;, score=0.897 total time=  21.0s
# [CV 5/5; 19/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 19/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  26.8s
# [CV 4/5; 28/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4
# [CV 4/5; 28/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  30.4s
# [CV 1/5; 38/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 38/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=8;, score=0.893 total time=  33.0s
# [CV 1/5; 45/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12
# [CV 1/5; 45/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12;, score=0.895 total time=  31.7s
# [CV 1/5; 53/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 53/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8;, score=0.895 total time=  34.9s
# [CV 3/5; 61/81] START bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4
# [CV 3/5; 61/81] END bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  38.7s
# [CV 4/5; 69/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12
# [CV 4/5; 69/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  41.9s
# [CV 3/5; 77/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 77/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  46.6s
# [CV 1/5; 1/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=4
# [CV 1/5; 1/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=   2.5s
# [CV 1/5; 9/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12
# [CV 1/5; 9/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12;, score=0.894 total time=  10.1s
# [CV 2/5; 9/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12
# [CV 2/5; 9/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=12;, score=0.895 total time=  11.1s
# [CV 1/5; 15/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12
# [CV 1/5; 15/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  19.0s
# [CV 1/5; 19/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4
# [CV 1/5; 19/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  26.7s
# [CV 3/5; 28/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 28/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  29.8s
# [CV 2/5; 37/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=4
# [CV 2/5; 37/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  34.2s
# [CV 4/5; 45/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 45/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  32.6s
# [CV 3/5; 53/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 53/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  37.1s
# [CV 5/5; 61/81] START bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4
# [CV 5/5; 61/81] END bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4;, score=0.896 total time=  38.5s
# [CV 5/5; 69/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 69/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  42.0s
# [CV 5/5; 77/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 77/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  44.6s
# [CV 1/5; 7/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4
# [CV 1/5; 7/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=4;, score=0.894 total time=  17.4s
# [CV 5/5; 12/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=12
# [CV 5/5; 12/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=12;, score=0.897 total time=  20.7s
# [CV 3/5; 19/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 19/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  27.8s
# [CV 3/5; 30/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=12
# [CV 3/5; 30/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  29.3s
# [CV 2/5; 39/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=12
# [CV 2/5; 39/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  32.3s
# [CV 2/5; 45/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12
# [CV 2/5; 45/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=12;, score=0.898 total time=  33.1s
# [CV 4/5; 53/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8
# [CV 4/5; 53/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  30.7s
# [CV 1/5; 61/81] START bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4
# [CV 1/5; 61/81] END bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=4;, score=0.894 total time=  38.9s
# [CV 1/5; 69/81] START bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12
# [CV 1/5; 69/81] END bootstrap=True, max_features=9, min_samples_leaf=5, min_samples_split=12;, score=0.894 total time=  46.1s
# [CV 4/5; 77/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8
# [CV 4/5; 77/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  46.8s
# [CV 1/5; 5/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 5/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8;, score=0.895 total time=  17.0s
# [CV 5/5; 16/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=4
# [CV 5/5; 16/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=4;, score=0.898 total time=  19.6s
# [CV 4/5; 24/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=12
# [CV 4/5; 24/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  24.1s
# [CV 5/5; 32/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 32/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  28.0s
# [CV 2/5; 40/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 40/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=4;, score=0.897 total time=  32.5s
# [CV 1/5; 47/81] START bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 47/81] END bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=8;, score=0.893 total time=  37.6s
# [CV 4/5; 54/81] START bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 54/81] END bootstrap=True, max_features=7, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  34.6s
# [CV 1/5; 62/81] START bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 62/81] END bootstrap=True, max_features=8, min_samples_leaf=8, min_samples_split=8;, score=0.894 total time=  39.0s
# [CV 2/5; 70/81] START bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 70/81] END bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  41.4s
# [CV 2/5; 78/81] START bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 78/81] END bootstrap=True, max_features=10, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  42.2s
# [CV 2/5; 6/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 6/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12;, score=0.895 total time=  16.7s
# [CV 5/5; 11/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8
# [CV 5/5; 11/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8;, score=0.897 total time=  21.7s
# [CV 5/5; 20/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=8
# [CV 5/5; 20/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=8;, score=0.897 total time=  28.3s
# [CV 5/5; 31/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=4
# [CV 5/5; 31/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=4;, score=0.897 total time=  27.9s
# [CV 3/5; 38/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=8
# [CV 3/5; 38/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  33.9s
# ...
# [CV 5/5; 4/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  15.4s
# [CV 3/5; 17/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 17/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  20.9s
# [CV 5/5; 25/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=4
# [CV 5/5; 25/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=4;, score=0.897 total time=  23.0s
# [CV 5/5; 33/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 33/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  27.8s
# [CV 3/5; 41/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 41/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  32.2s
# [CV 4/5; 49/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4
# [CV 4/5; 49/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  35.6s
# [CV 3/5; 55/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 55/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=4;, score=0.894 total time=  42.0s
# [CV 5/5; 64/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 64/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  48.4s
# [CV 1/5; 73/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4
# [CV 1/5; 73/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4;, score=0.892 total time=  52.0s
# [CV 1/5; 81/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12
# [CV 1/5; 81/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12;, score=0.893 total time=  20.3s
# [CV 3/5; 5/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 5/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  18.0s
# [CV 3/5; 11/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8
# [CV 3/5; 11/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  20.8s
# [CV 2/5; 18/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12
# [CV 2/5; 18/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  22.8s
# [CV 2/5; 26/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8
# [CV 2/5; 26/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  21.1s
# [CV 2/5; 34/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4
# [CV 2/5; 34/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4;, score=0.898 total time=  25.1s
# [CV 1/5; 42/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12
# [CV 1/5; 42/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12;, score=0.894 total time=  31.3s
# [CV 2/5; 50/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 50/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  37.1s
# [CV 2/5; 58/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 58/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4;, score=0.897 total time=  40.8s
# [CV 2/5; 66/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12
# [CV 2/5; 66/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  43.8s
# [CV 5/5; 73/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 73/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4;, score=0.894 total time=  51.4s
# [CV 4/5; 81/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 81/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  19.7s
# [CV 5/5; 8/81] START bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 8/81] END bootstrap=True, max_features=2, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  15.5s
# [CV 3/5; 14/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8
# [CV 3/5; 14/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=8;, score=0.897 total time=  20.7s
# [CV 2/5; 21/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12
# [CV 2/5; 21/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12;, score=0.898 total time=  24.8s
# [CV 2/5; 27/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12
# [CV 2/5; 27/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  24.9s
# [CV 2/5; 35/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8
# [CV 2/5; 35/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=8;, score=0.898 total time=  26.3s
# [CV 1/5; 43/81] START bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4
# [CV 1/5; 43/81] END bootstrap=True, max_features=6, min_samples_leaf=8, min_samples_split=4;, score=0.895 total time=  27.0s
# [CV 5/5; 50/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8
# [CV 5/5; 50/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  35.9s
# [CV 3/5; 58/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 58/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4;, score=0.895 total time=  39.9s
# [CV 4/5; 66/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 66/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  44.4s
# [CV 2/5; 74/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8
# [CV 2/5; 74/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  50.4s
# [CV 5/5; 81/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 81/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  18.4s
# [CV 2/5; 2/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8
# [CV 2/5; 2/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  20.4s
# [CV 3/5; 15/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12
# [CV 3/5; 15/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  20.3s
# [CV 2/5; 22/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 22/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  26.4s
# [CV 4/5; 30/81] START bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 30/81] END bootstrap=True, max_features=5, min_samples_leaf=3, min_samples_split=12;, score=0.896 total time=  28.3s
# [CV 2/5; 38/81] START bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=8
# [CV 2/5; 38/81] END bootstrap=True, max_features=6, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  34.4s
# [CV 3/5; 46/81] START bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 46/81] END bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=4;, score=0.893 total time=  40.3s
# [CV 3/5; 57/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=12
# [CV 3/5; 57/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=12;, score=0.895 total time=  40.8s
# [CV 5/5; 65/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8
# [CV 5/5; 65/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  47.2s
# [CV 5/5; 72/81] START bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=12
# [CV 5/5; 72/81] END bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=12;, score=0.897 total time=  47.1s
# [CV 5/5; 80/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=8
# [CV 5/5; 80/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  26.6s
# [CV 3/5; 1/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 1/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  17.1s
# [CV 3/5; 10/81] START bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4
# [CV 3/5; 10/81] END bootstrap=True, max_features=3, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  21.2s
# [CV 1/5; 18/81] START bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12
# [CV 1/5; 18/81] END bootstrap=True, max_features=3, min_samples_leaf=8, min_samples_split=12;, score=0.895 total time=  20.9s
# [CV 1/5; 26/81] START bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8
# [CV 1/5; 26/81] END bootstrap=True, max_features=4, min_samples_leaf=8, min_samples_split=8;, score=0.895 total time=  21.7s
# [CV 1/5; 34/81] START bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4
# [CV 1/5; 34/81] END bootstrap=True, max_features=5, min_samples_leaf=8, min_samples_split=4;, score=0.895 total time=  26.8s
# [CV 2/5; 42/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 42/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  30.2s
# [CV 1/5; 50/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 50/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=8;, score=0.894 total time=  35.6s
# [CV 1/5; 58/81] START bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4
# [CV 1/5; 58/81] END bootstrap=True, max_features=8, min_samples_leaf=5, min_samples_split=4;, score=0.894 total time=  38.3s
# [CV 3/5; 65/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8
# [CV 3/5; 65/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8;, score=0.894 total time=  47.4s
# [CV 4/5; 72/81] START bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=12
# [CV 4/5; 72/81] END bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  46.4s
# [CV 3/5; 80/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=8
# [CV 3/5; 80/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=8;, score=0.897 total time=  27.6s
# [CV 1/5; 2/81] START bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 2/81] END bootstrap=True, max_features=2, min_samples_leaf=3, min_samples_split=8;, score=0.895 total time=  19.1s
# [CV 2/5; 15/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12
# [CV 2/5; 15/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=12;, score=0.897 total time=  22.0s
# [CV 2/5; 23/81] START bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8
# [CV 2/5; 23/81] END bootstrap=True, max_features=4, min_samples_leaf=5, min_samples_split=8;, score=0.896 total time=  25.6s
# [CV 2/5; 31/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 31/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=4;, score=0.897 total time=  31.0s
# [CV 1/5; 41/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 41/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=8;, score=0.894 total time=  33.3s
# [CV 2/5; 49/81] START bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4
# [CV 2/5; 49/81] END bootstrap=True, max_features=7, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  37.3s
# [CV 5/5; 56/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=8
# [CV 5/5; 56/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  40.4s
# [CV 2/5; 64/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=4
# [CV 2/5; 64/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=4;, score=0.895 total time=  48.1s
# [CV 3/5; 72/81] START bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=12
# [CV 3/5; 72/81] END bootstrap=True, max_features=9, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  47.5s
# [CV 4/5; 80/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=8
# [CV 4/5; 80/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=8;, score=0.896 total time=  27.1s
# [CV 5/5; 6/81] START bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12
# [CV 5/5; 6/81] END bootstrap=True, max_features=2, min_samples_leaf=5, min_samples_split=12;, score=0.896 total time=  17.8s
# [CV 3/5; 13/81] START bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4
# [CV 3/5; 13/81] END bootstrap=True, max_features=3, min_samples_leaf=5, min_samples_split=4;, score=0.897 total time=  21.7s
# [CV 4/5; 21/81] START bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12
# [CV 4/5; 21/81] END bootstrap=True, max_features=4, min_samples_leaf=3, min_samples_split=12;, score=0.897 total time=  27.7s
# [CV 1/5; 32/81] START bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8
# [CV 1/5; 32/81] END bootstrap=True, max_features=5, min_samples_leaf=5, min_samples_split=8;, score=0.894 total time=  30.3s
# [CV 5/5; 40/81] START bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=4
# [CV 5/5; 40/81] END bootstrap=True, max_features=6, min_samples_leaf=5, min_samples_split=4;, score=0.896 total time=  32.3s
# [CV 5/5; 47/81] START bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=8
# [CV 5/5; 47/81] END bootstrap=True, max_features=7, min_samples_leaf=3, min_samples_split=8;, score=0.896 total time=  37.8s
# [CV 5/5; 55/81] START bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=4
# [CV 5/5; 55/81] END bootstrap=True, max_features=8, min_samples_leaf=3, min_samples_split=4;, score=0.896 total time=  41.8s
# [CV 1/5; 65/81] START bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8
# [CV 1/5; 65/81] END bootstrap=True, max_features=9, min_samples_leaf=3, min_samples_split=8;, score=0.893 total time=  48.3s
# [CV 2/5; 73/81] START bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4
# [CV 2/5; 73/81] END bootstrap=True, max_features=10, min_samples_leaf=3, min_samples_split=4;, score=0.894 total time=  52.4s
# [CV 2/5; 81/81] START bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12
# [CV 2/5; 81/81] END bootstrap=True, max_features=10, min_samples_leaf=8, min_samples_split=12;, score=0.896 total time=  21.5s
