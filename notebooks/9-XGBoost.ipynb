# %% [markdown]
# # XGBoost

# %% [markdown]
# ## Libraries

# %%
from sklearnex import patch_sklearn 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
patch_sklearn()
from xgboost import XGBClassifier
from collections import Counter
from imblearn.over_sampling import SMOTE, ADASYN, SMOTENC
from imblearn.combine import SMOTETomek, SMOTEENN 
import matplotlib.pyplot as plt
from numpy import where
import time
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
df_train = pd.read_csv('../data/df_train.csv')
df_test = pd.read_csv('../data/df_test.csv')

X_train = df_train.drop('kill', axis=1)
y_train = df_train['kill']
X_test = df_test.drop(['kill'], axis=1)
y_test = df_test['kill']

X_train = X_train.values
y_train = y_train.values
X_test = X_test.values
y_test = y_test.values

# %%
def fit_and_print(model, X_train, y_train):
    model.fit(X_train, y_train)  
    y_pred = model.predict(X_test)
    print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))  
    print("Classification Report: \n", classification_report(y_test, y_pred))  
    print("Accuracy: ", round(accuracy_score(y_test, y_pred),3))
    print("Precision:", round(precision_score(y_test, y_pred),3))
    print("Recall:", round(recall_score(y_test, y_pred),3))
    print("f1: ", round(f1_score(y_test, y_pred),3))

# %%
model = XGBClassifier(random_state=42, use_label_encoder=False)

# %%
fit_and_print(model, X_train, y_train)
# Out:
# [01:10:22] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion Matrix:
#  [[19815   406]
#  [ 2075   745]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94     20221
#            1       0.65      0.26      0.38      2820
#
#     accuracy                           0.89     23041
#    macro avg       0.78      0.62      0.66     23041
# weighted avg       0.87      0.89      0.87     23041
#
# Accuracy:  0.892
# Precision: 0.647
# Recall: 0.264
# f1:  0.375

# %% [markdown]
# ## GridSearch

# %%
param_grid = {
        'gamma': [0.5, 1, 1.5],
        'subsample': [0.6, 0.8],
        'colsample_bytree': [0.6, 0.8],
        'max_depth': [3, 4, 5]
}

# %%
# Create a based model
xgboost = XGBClassifier(random_state=42, use_label_encoder=False)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgboost, param_grid = param_grid, cv = 5, n_jobs = -1, verbose = 10)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 5/5; 7/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6..
# [01:10:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 7/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.895 total time=12.4min
# [CV 5/5; 10/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8.
# [01:23:08] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 10/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.895 total time=17.8min
# [CV 4/5; 20/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8
# [01:40:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 20/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.895 total time=12.1min
# [CV 4/5; 26/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8.
# [01:52:56] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 26/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.895 total time=12.2min
# [CV 4/5; 32/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8
# [02:05:13] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 32/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8;, score=0.895 total time=11.9min
# [CV 2/5; 2/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8
# [01:10:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 2/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.895 total time= 9.6min
# [CV 4/5; 9/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6..
# [01:20:17] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 9/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.894 total time=17.5min
# [CV 4/5; 18/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8
# [01:37:52] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 18/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8;, score=0.895 total time=21.9min
# [CV 2/5; 28/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8.
# [01:59:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 28/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.897 total time=17.5min
# [CV 5/5; 3/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6
# [01:10:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 3/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.897 total time=14.0min
# [CV 4/5; 13/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6
# [01:24:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 13/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6;, score=0.894 total time=12.6min
# [CV 2/5; 18/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8
# [01:37:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 18/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8;, score=0.897 total time=22.0min
# [CV 1/5; 28/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8.
# [01:59:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 28/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.895 total time=18.0min
# [CV 2/5; 7/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6..
# [01:10:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 7/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.895 total time= 9.9min
# [CV 5/5; 9/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6..
# [01:20:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 9/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.896 total time=17.0min
# [CV 3/5; 18/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8
# [01:37:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 18/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8;, score=0.896 total time=22.4min
# [CV 5/5; 28/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8.
# [02:00:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 28/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.896 total time=17.2min
# [CV 1/5; 3/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6
# [01:10:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 3/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.894 total time=15.7min
# [CV 5/5; 13/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6
# [01:26:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 13/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6;, score=0.895 total time=12.2min
# [CV 5/5; 18/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8
# [01:38:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 18/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8;, score=0.896 total time=21.4min
# [CV 4/5; 28/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8.
# [02:00:02] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 28/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.894 total time=17.3min
# [CV 2/5; 3/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6
# [01:10:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 3/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.896 total time=12.3min
# [CV 4/5; 10/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8.
# [01:22:56] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 10/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.895 total time=17.7min
# [CV 3/5; 20/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8
# [01:40:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 20/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.896 total time=11.8min
# [CV 1/5; 26/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8.
# [01:52:21] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 26/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.893 total time=12.2min
# [CV 1/5; 32/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8
# [02:04:34] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 32/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8;, score=0.893 total time=12.9min
# [CV 1/5; 2/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8
# [01:10:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 2/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.894 total time=11.9min
# [CV 3/5; 10/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8.
# [01:22:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 10/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.897 total time=17.3min
# [CV 1/5; 20/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8
# [01:39:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 20/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.893 total time=12.8min
# [CV 3/5; 26/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8.
# [01:52:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 26/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.897 total time=12.2min
# [CV 2/5; 32/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8
# [02:04:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 32/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8;, score=0.896 total time=12.7min
# [CV 2/5; 8/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8..
# [01:10:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 8/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.895 total time=13.8min
# [CV 2/5; 13/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6
# [01:24:31] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 13/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6;, score=0.895 total time=12.6min
# [CV 1/5; 18/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8
# [01:37:15] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 18/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.8;, score=0.894 total time=22.6min
# [CV 3/5; 28/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8.
# [01:59:49] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 28/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.896 total time=17.9min
# [CV 4/5; 3/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6
# [01:10:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 3/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.895 total time=17.4min
# [CV 4/5; 14/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8
# [01:28:01] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 14/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8;, score=0.894 total time=12.2min
# [CV 2/5; 20/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8
# [01:40:13] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 20/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.895 total time=12.3min
# [CV 2/5; 26/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8.
# [01:52:30] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 26/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.896 total time=12.6min
# [CV 3/5; 32/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8
# [02:05:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 32/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8;, score=0.896 total time=12.6min
# [CV 3/5; 4/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8
# [01:10:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 4/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.896 total time=19.1min
# [CV 5/5; 14/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8
# [01:29:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 14/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8;, score=0.896 total time=12.1min
# [CV 5/5; 20/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8
# [01:41:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 20/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.894 total time=12.2min
# [CV 5/5; 26/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8.
# [01:54:04] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 26/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.894 total time=11.6min
# [CV 5/5; 32/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8
# [02:05:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 32/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.8;, score=0.894 total time=12.6min
# [CV 4/5; 1/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6
# [01:10:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 1/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.895 total time=13.7min
# [CV 4/5; 12/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8.
# [01:24:22] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 12/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.895 total time=20.2min
# [CV 5/5; 21/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6
# [01:44:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 21/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.897 total time=16.6min
# [CV 2/5; 29/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6.
# [02:01:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 29/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.896 total time=20.4min
# [CV 5/5; 8/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8..
# [01:10:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 8/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.896 total time=13.1min
# [CV 3/5; 11/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6.
# [01:23:57] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 11/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.894 total time=20.2min
# [CV 3/5; 21/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6
# [01:44:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 21/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.897 total time=16.8min
# [CV 1/5; 29/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6.
# [02:01:00] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 29/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.893 total time=21.0min
# [02:27:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=42,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, subsample=None,
#                                      tree_method=None, use_label_encoder=False,
#                                      validate_parameters=None, verbosity=None),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8], 'gamma': [0.5, 1, 1.5],
#                          'max_depth': [3, 4, 5], 'subsample': [0.6, 0.8]},
#              verbose=10)

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.8, 'gamma': 1.5, 'max_depth': 5, 'subsample': 0.8}

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=1.5, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=40, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
grid_search.best_score_
# Out:
# 0.895829663386053

# %%
fit_and_print(best_grid,X_train,y_train)
# Out:
# [02:27:10] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion Matrix:
#  [[19830   391]
#  [ 2101   719]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     20221
#            1       0.65      0.25      0.37      2820
#
#     accuracy                           0.89     23041
#    macro avg       0.78      0.62      0.65     23041
# weighted avg       0.87      0.89      0.87     23041
#
# Accuracy:  0.892
# Precision: 0.648
# Recall: 0.255
# f1:  0.366

# %%
def calculate_pred_and_inf_time(best_grid, X_test):
    # get the start time
    st_wall_inf = time.time()

    # Generate generalization metrics
    grid_predictions = best_grid.predict(X_test)

    # get the end time
    et_wall_inf = time.time()

    # get execution time
    wall_time_inf = et_wall_inf - st_wall_inf
    print(f'Inference Time: {1000*wall_time_inf:.3f} miliseconds')

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Inference Time: 17.076 miliseconds

# %% [markdown]
# ## Resampling

# %% [markdown]
# ### SMOTE

# %%
# Oversample and plot imbalanced dataset with SMOTE

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = SMOTE(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# [CV 3/5; 7/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6..
# [01:10:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 7/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.896 total time=12.7min
# [CV 1/5; 11/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6.
# [01:23:27] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 11/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.893 total time=21.7min
# [CV 4/5; 22/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8
# [01:45:04] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 22/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.895 total time=17.2min
# [CV 2/5; 30/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8.
# [02:02:17] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 30/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.896 total time=20.2min
# Counter({0: 114988, 1: 114988})
# [02:27:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 7/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6..
# [01:10:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 7/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.894 total time=13.7min
# [CV 5/5; 12/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8.
# [01:24:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 12/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.896 total time=20.6min
# [CV 2/5; 22/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8
# [01:44:56] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 22/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.897 total time=16.2min
# [CV 3/5; 29/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6.
# [02:01:17] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 29/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.896 total time=21.3min
# Confusion Matrix:
#  [[17350  2871]
#  [ 1147  1673]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90     20221
#            1       0.37      0.59      0.45      2820
#
#     accuracy                           0.83     23041
#    macro avg       0.65      0.73      0.68     23041
# weighted avg       0.87      0.83      0.84     23041
#
# Accuracy:  0.826
# Precision: 0.368
# Recall: 0.593
# f1:  0.454
# Inference Time: 6.600 miliseconds

# %% [markdown]
# ### ADASYN

# %%
# Oversample and plot imbalanced dataset with ADASYN

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = ADASYN(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({0: 114988, 1: 112141})
# [02:27:25] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 1/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6
# [01:10:36] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 1/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.895 total time=13.5min
# [CV 3/5; 12/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8.
# [01:24:17] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 12/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.897 total time=20.1min
# [CV 4/5; 21/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6
# [01:44:19] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 21/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.895 total time=17.5min
# [CV 1/5; 30/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8.
# [02:01:56] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 30/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.894 total time=20.8min
# [CV 2/5; 1/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6
# [01:10:34] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 1/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.895 total time=13.3min
# [CV 4/5; 11/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6.
# [01:23:57] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 11/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.894 total time=20.1min
# [CV 2/5; 21/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6
# [01:43:58] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 21/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.896 total time=17.6min
# [CV 5/5; 29/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6.
# [02:01:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 29/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.896 total time=21.1min
# [CV 4/5; 7/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6..
# [01:10:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 7/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.894 total time=12.9min
# [CV 2/5; 11/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6.
# [01:23:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 11/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.895 total time=20.3min
# [CV 1/5; 21/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6
# [01:43:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 21/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.893 total time=17.6min
# [CV 4/5; 29/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6.
# [02:01:33] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 29/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.894 total time=21.2min
# Confusion Matrix:
#  [[16953  3268]
#  [ 1085  1735]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89     20221
#            1       0.35      0.62      0.44      2820
#
#     accuracy                           0.81     23041
#    macro avg       0.64      0.73      0.66     23041
# weighted avg       0.87      0.81      0.83     23041
#
# Accuracy:  0.811
# Precision: 0.347
# Recall: 0.615
# f1:  0.444
# Inference Time: 6.395 miliseconds

# %% [markdown]
# ### SMOTE and TL

# %%
# Oversample and plot imbalanced dataset with SMOTE and TL

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = SMOTETomek(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({0: 106266, 1: 106266})
# [02:31:21] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion Matrix:
#  [[17283  2938]
#  [ 1104  1716]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.85      0.90     20221
#            1       0.37      0.61      0.46      2820
#
#     accuracy                           0.82     23041
#    macro avg       0.65      0.73      0.68     23041
# weighted avg       0.87      0.82      0.84     23041
#
# Accuracy:  0.825
# Precision: 0.369
# Recall: 0.609
# f1:  0.459
# Inference Time: 6.176 miliseconds
# [CV 3/5; 3/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6
# [01:10:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 3/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.897 total time=11.2min
# [CV 1/5; 10/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8.
# [01:21:58] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 10/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.894 total time=17.5min
# [CV 5/5; 19/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6
# [01:39:17] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 19/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.895 total time=12.5min
# [CV 5/5; 25/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6.
# [01:51:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 25/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.895 total time=11.9min
# [CV 4/5; 31/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6
# [02:03:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 31/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6;, score=0.895 total time=13.4min
# [CV 4/5; 36/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8
# [02:17:09] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 36/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8;, score=0.896 total time= 9.6min
# [CV 3/5; 2/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8
# [01:10:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 2/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.896 total time=14.0min
# [CV 3/5; 13/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6
# [01:24:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 13/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6;, score=0.896 total time=12.5min
# [CV 5/5; 17/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6
# [01:37:14] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 17/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6;, score=0.895 total time=21.0min
# [CV 3/5; 27/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6.
# [01:58:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 27/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.897 total time=17.7min
# [CV 2/5; 36/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8
# [02:15:57] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 36/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8;, score=0.896 total time=11.2min
# [CV 5/5; 2/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8
# [01:10:36] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 2/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.896 total time= 7.3min
# [CV 1/5; 9/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6..
# [01:17:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 9/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.894 total time=17.4min
# [CV 1/5; 17/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6
# [01:35:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 17/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6;, score=0.894 total time=21.5min
# [CV 1/5; 27/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6.
# [01:56:52] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 27/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.894 total time=17.5min
# [CV 1/5; 35/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6
# [02:14:24] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 35/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6;, score=0.893 total time=12.8min
# [CV 1/5; 8/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8..
# [01:10:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 8/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.894 total time= 8.7min
# [CV 2/5; 9/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6..
# [01:19:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 9/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.895 total time=16.9min
# [CV 2/5; 17/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6
# [01:36:26] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 17/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6;, score=0.896 total time=21.2min
# [CV 2/5; 27/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6.
# [01:57:36] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 27/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.896 total time=17.3min
# [CV 3/5; 35/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6
# [02:15:02] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 35/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6;, score=0.896 total time=12.3min
# [CV 3/5; 8/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8..
# [01:10:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 8/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.896 total time= 9.0min
# [CV 3/5; 9/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6..
# [01:19:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 9/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.896 total time=17.3min
# [CV 4/5; 17/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6
# [01:37:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 17/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6;, score=0.894 total time=21.6min
# [CV 4/5; 27/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6.
# [01:58:34] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 27/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.895 total time=17.3min
# [CV 3/5; 36/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8
# [02:15:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 36/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8;, score=0.896 total time=11.4min
# [CV 3/5; 6/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8
# [01:10:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 6/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.896 total time=23.7min
# [CV 5/5; 16/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8
# [01:34:31] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 16/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8;, score=0.896 total time=16.9min
# [CV 3/5; 25/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6.
# [01:51:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 25/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.897 total time=11.6min
# [CV 2/5; 31/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6
# [02:02:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 31/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6;, score=0.895 total time=12.1min
# [CV 4/5; 35/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6
# [02:15:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 35/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6;, score=0.895 total time=12.2min
# [CV 1/5; 4/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8
# [01:10:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 4/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.893 total time=11.5min
# [CV 2/5; 10/36] START colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8.
# [01:22:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 10/36] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.896 total time=17.0min
# [CV 4/5; 19/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6
# [01:39:09] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 19/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.894 total time=12.3min
# [CV 4/5; 25/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6.
# [01:51:24] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 25/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.895 total time=12.4min
# [CV 5/5; 31/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6
# [02:03:48] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 31/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6;, score=0.895 total time=12.0min
# [CV 1/5; 36/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8
# [02:15:55] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 36/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8;, score=0.894 total time=11.5min
# [CV 4/5; 8/36] START colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8..
# [01:10:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 8/36] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.895 total time=13.7min
# [CV 1/5; 13/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6
# [01:24:27] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 13/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.6;, score=0.894 total time=12.3min
# [CV 3/5; 17/36] START colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6
# [01:36:49] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 17/36] END colsample_bytree=0.6, gamma=1.5, max_depth=5, subsample=0.6;, score=0.895 total time=22.4min
# [CV 5/5; 27/36] START colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6.
# [01:59:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 27/36] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.897 total time=18.0min
# [CV 5/5; 36/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8
# [02:17:08] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 36/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.8;, score=0.896 total time=10.2min

# %% [markdown]
# ### SMOTE and ENN

# %%
# Oversample and plot imbalanced dataset with SMOTE and ENN

# summarize class distribution
counter = Counter(y_train)
print(counter)
# transform the dataset
oversample = SMOTEENN(random_state=42)
X_train_rel, y_train_rel = oversample.fit_resample(X_train, y_train)
# summarize the new class distribution
counter = Counter(y_train_rel)
print(counter)

fit_and_print(best_grid, X_train_rel, y_train_rel)

calculate_pred_and_inf_time(best_grid, X_test)
# Out:
# Counter({0: 114988, 1: 15577})
# Counter({1: 79510, 0: 69097})
# [02:27:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion Matrix:
#  [[16255  3966]
#  [  849  1971]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87     20221
#            1       0.33      0.70      0.45      2820
#
#     accuracy                           0.79     23041
#    macro avg       0.64      0.75      0.66     23041
# weighted avg       0.87      0.79      0.82     23041
#
# Accuracy:  0.791
# Precision: 0.332
# Recall: 0.699
# f1:  0.45
# Inference Time: 6.791 miliseconds
# [CV 4/5; 2/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8
# [01:10:36] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 2/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.895 total time=13.3min
# [CV 1/5; 12/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8.
# [01:24:00] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 12/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.894 total time=20.9min
# [CV 1/5; 22/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8
# [01:44:55] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 22/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.894 total time=17.5min
# [CV 3/5; 30/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8.
# [02:02:22] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 30/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.896 total time=20.7min
# [CV 1/5; 1/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6
# [01:10:36] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 1/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.894 total time=13.3min
# [CV 5/5; 11/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6.
# [01:24:02] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 11/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.895 total time=21.6min
# [CV 5/5; 22/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8
# [01:45:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 22/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.896 total time=17.0min
# [CV 4/5; 30/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8.
# [02:02:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 30/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.894 total time=20.5min
# [CV 3/5; 1/36] START colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6
# [01:10:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 1/36] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.896 total time=13.4min
# [CV 2/5; 12/36] START colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8.
# [01:24:07] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 12/36] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.897 total time=20.9min
# [CV 3/5; 22/36] START colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8
# [01:45:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 22/36] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.897 total time=17.6min
# [CV 5/5; 30/36] START colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8.
# [02:02:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 30/36] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.896 total time=20.9min
# [CV 4/5; 5/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6
# [01:10:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 5/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.894 total time=21.7min
# [CV 2/5; 15/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6
# [01:32:25] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 15/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6;, score=0.896 total time=15.7min
# [CV 1/5; 23/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6
# [01:48:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 23/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.894 total time=22.9min
# [CV 1/5; 33/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6
# [02:11:00] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 33/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6;, score=0.894 total time=13.8min
# [CV 5/5; 5/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6
# [01:10:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 5/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.895 total time=22.1min
# [CV 4/5; 15/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6
# [01:32:48] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 15/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6;, score=0.894 total time=16.3min
# [CV 4/5; 23/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6
# [01:49:15] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 23/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.894 total time=22.3min
# [CV 4/5; 33/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6
# [02:11:28] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 33/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6;, score=0.895 total time=13.4min
# [CV 1/5; 5/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6
# [01:10:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 5/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.894 total time=22.3min
# [CV 5/5; 15/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6
# [01:33:01] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 15/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6;, score=0.897 total time=17.1min
# [CV 3/5; 24/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8
# [01:50:10] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 24/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.896 total time=22.4min
# [CV 2/5; 34/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8
# [02:12:32] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 34/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8;, score=0.897 total time=12.4min
# [CV 1/5; 6/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8
# [01:10:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 6/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.893 total time=22.5min
# [CV 3/5; 16/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8
# [01:33:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 16/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8;, score=0.897 total time=16.3min
# [CV 1/5; 24/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8
# [01:49:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 24/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.894 total time=21.7min
# [CV 3/5; 33/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6
# [02:11:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 33/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6;, score=0.895 total time=13.7min
# [CV 3/5; 5/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6
# [01:10:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 5/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.896 total time=22.0min
# [CV 3/5; 15/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6
# [01:32:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 15/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6;, score=0.896 total time=16.2min
# [CV 2/5; 23/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6
# [01:48:58] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 23/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.895 total time=22.2min
# [CV 2/5; 33/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6
# [02:11:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 33/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6;, score=0.895 total time=13.9min
# [CV 2/5; 5/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6
# [01:10:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 5/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.896 total time=22.4min
# [CV 1/5; 16/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8
# [01:33:08] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 16/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8;, score=0.894 total time=16.0min
# [CV 3/5; 23/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6
# [01:49:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 23/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.896 total time=22.5min
# [CV 5/5; 33/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6
# [02:11:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 33/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.6;, score=0.896 total time=13.5min
# [CV 4/5; 6/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8
# [01:10:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 6/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.894 total time=22.4min
# [CV 2/5; 16/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8
# [01:33:07] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 16/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8;, score=0.896 total time=16.1min
# [CV 5/5; 23/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6
# [01:49:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 23/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.896 total time=23.0min
# [CV 1/5; 34/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8
# [02:12:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 34/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8;, score=0.894 total time=13.0min
# [CV 2/5; 6/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8
# [01:10:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 6/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.896 total time=21.7min
# [CV 1/5; 15/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6
# [01:32:30] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 15/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.6;, score=0.894 total time=17.1min
# [CV 2/5; 24/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8
# [01:49:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 24/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.896 total time=23.5min
# [CV 3/5; 34/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8
# [02:13:07] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 34/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8;, score=0.897 total time=12.2min
# [CV 4/5; 4/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8
# [01:10:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 4/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.895 total time=17.1min
# [CV 2/5; 14/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8
# [01:27:44] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 14/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8;, score=0.896 total time=10.9min
# [CV 1/5; 19/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6
# [01:38:40] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 19/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.893 total time=12.0min
# [CV 5/5; 24/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8
# [01:50:48] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 24/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.896 total time=23.0min
# [CV 4/5; 34/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8
# [02:13:47] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 34/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8;, score=0.895 total time=11.7min
# [CV 5/5; 6/36] START colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8
# [01:10:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 6/36] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.896 total time=23.2min
# [CV 4/5; 16/36] START colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8
# [01:33:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 16/36] END colsample_bytree=0.6, gamma=1.5, max_depth=4, subsample=0.8;, score=0.895 total time=16.7min
# [CV 4/5; 24/36] START colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8
# [01:50:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 24/36] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.895 total time=23.3min
# [CV 5/5; 34/36] START colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8
# [02:13:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 34/36] END colsample_bytree=0.8, gamma=1.5, max_depth=4, subsample=0.8;, score=0.895 total time=11.9min
# [CV 2/5; 4/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8
# [01:10:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 4/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.896 total time=17.3min
# [CV 3/5; 14/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8
# [01:27:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 14/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8;, score=0.896 total time=11.2min
# [CV 3/5; 19/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6
# [01:39:09] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 19/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.897 total time=11.7min
# [CV 1/5; 25/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6.
# [01:50:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 25/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.893 total time=11.9min
# [CV 1/5; 31/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6
# [02:02:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 31/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6;, score=0.893 total time=11.8min
# [CV 2/5; 35/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6
# [02:14:39] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 35/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6;, score=0.895 total time=11.6min
# [CV 5/5; 4/36] START colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8
# [01:10:42] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 4/36] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.895 total time=16.8min
# [CV 1/5; 14/36] START colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8
# [01:27:25] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 14/36] END colsample_bytree=0.6, gamma=1.5, max_depth=3, subsample=0.8;, score=0.894 total time=11.5min
# [CV 2/5; 19/36] START colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6
# [01:38:59] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 19/36] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.894 total time=11.9min
# [CV 2/5; 25/36] START colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6.
# [01:50:56] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 25/36] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.895 total time=12.4min
# [CV 3/5; 31/36] START colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6
# [02:03:21] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 31/36] END colsample_bytree=0.8, gamma=1.5, max_depth=3, subsample=0.6;, score=0.896 total time=11.8min
# [CV 5/5; 35/36] START colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6
# [02:15:14] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 35/36] END colsample_bytree=0.8, gamma=1.5, max_depth=5, subsample=0.6;, score=0.895 total time=11.0min
